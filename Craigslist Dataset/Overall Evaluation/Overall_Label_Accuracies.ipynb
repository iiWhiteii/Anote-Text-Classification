# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bert_label_accuracies = pd.read_csv('Craigslist_Data_Label_Accuracies.csv.csv')
rnn_label_accuracies = pd.read_csv('RNN_Craigslist_labels_metrics_result.csv')
ft_gpt_label_accuracies = pd.read_csv('ft_craigslist_labels_metrics_results.csv')

# %%
rnn_label_accuracies
# Out:
#     Label  accuracy  precision    recall        f1
# 0      10     0.280   0.721258  0.205467  0.135890
# 1      20     0.301   0.368759  0.199081  0.161908
# 2      30     0.265   0.216315  0.206495  0.183721
# 3      40     0.267   0.216479  0.212833  0.198826
# 4      50     0.266   0.237122  0.221338  0.208773
# 5      60     0.276   0.236176  0.231352  0.228318
# 6      70     0.289   0.251256  0.241863  0.236209
# 7      80     0.301   0.259076  0.245940  0.242379
# 8      90     0.269   0.237893  0.238658  0.236455
# 9     100     0.302   0.290531  0.259774  0.253630
# 10    110     0.294   0.267201  0.267253  0.264970
# 11    120     0.334   0.318076  0.291376  0.292170
# 12    130     0.327   0.297280  0.289725  0.285583
# 13    140     0.345   0.310866  0.304074  0.302077
# 14    150     0.340   0.311895  0.298335  0.297346

# %% [markdown]
# #  Accuracy, Precision, Recall Comparison Plot

# %%
import matplotlib.pyplot as plt

# Assuming you have loaded your data into variables bert_label_accuracies, rnn_label_accuracies, and ft_gpt_label_accuracies

plt.figure(figsize=(15, 5))

# Plot Accuracy
plt.subplot(1, 3, 1)
plt.plot(bert_label_accuracies['Labels'], bert_label_accuracies['accuracy'], label='BERT', marker='o', linestyle='-', color='blue', linewidth=2)
plt.plot(rnn_label_accuracies['Label'], rnn_label_accuracies['accuracy'], label='RNN', marker='s', linestyle='--', color='green', linewidth=2)
plt.plot(ft_gpt_label_accuracies['label'], ft_gpt_label_accuracies['accuracy'], label='FT-GPT', marker='^', linestyle='-', color='orange', linewidth=2)

plt.xlabel('Labels')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison')
plt.legend()

# Plot Precision
plt.subplot(1, 3, 2)
plt.plot(bert_label_accuracies['Labels'], bert_label_accuracies['precision'], label='BERT', marker='o', linestyle='-', color='blue', linewidth=2)
plt.plot(rnn_label_accuracies['Label'], rnn_label_accuracies['precision'], label='RNN', marker='s', linestyle='--', color='green', linewidth=2)
plt.plot(ft_gpt_label_accuracies['label'], ft_gpt_label_accuracies['precision'], label='FT-GPT', marker='^', linestyle='-', color='orange', linewidth=2)

plt.xlabel('Labels')
plt.ylabel('Precision')
plt.title('Precision Comparison')
plt.legend()

# Plot Recall
plt.subplot(1, 3, 3)
plt.plot(bert_label_accuracies['Labels'], bert_label_accuracies['recall'], label='BERT', marker='o', linestyle='-', color='blue', linewidth=2)
plt.plot(rnn_label_accuracies['Label'], rnn_label_accuracies['recall'], label='RNN', marker='s', linestyle='--', color='green', linewidth=2)
plt.plot(ft_gpt_label_accuracies['label'], ft_gpt_label_accuracies['recall'], label='FT-GPT', marker='^', linestyle='-', color='orange', linewidth=2)

plt.xlabel('Labels')
plt.ylabel('Recall')
plt.title('Recall Comparison')
plt.legend()

plt.suptitle('Performance Comparison on Craigslist Dataset')

plt.tight_layout()  # Adjust layout to prevent overlap
plt.show()
