# %%
import os
import openai
import json
import numpy as np
import pandas as pd
from datasets import load_dataset as ld
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
import time

# %%
from datasets import load_dataset as ld

def load_dataset_as_pandas_dataframe(
    dataset_name: str="trec"
):

    dataset = ld(dataset_name)
    df = dataset["train"].to_pandas()
    df = df.sample(frac=1)

    df_test = dataset["test"].to_pandas()
    df_test = df_test.sample(frac=1)
    
    return df, df_test

# %%
df, df_test = load_dataset_as_pandas_dataframe()

# %%
# Out:
#                                                   text  coarse_label  \
# 460                  What did Jesse Jackson organize ?             3
# 348       What year did the Andy Griffith show begin ?             5
# 169                   Who founded American Red Cross ?             3
# 466                           What are pediatricians ?             2
# 13   Who was the first man to fly across the Pacifi...             3
# ..                                                 ...           ...
# 347   What is the effect of volcanoes on the climate ?             2
# 201  What city 's newspaper is called `` The Enquir...             4
# 54          What is done with worn or outdated flags ?             2
# 209                  What is the effect of acid rain ?             2
# 149                                 What is nicotine ?             2
#
#      fine_label
# 460          28
# 348          39
# 169          29
# 466          24
# 13           29
# ..          ...
# 347          25
# 201          32
# 54           25
# 209          25
# 149          24
#
# [500 rows x 3 columns]
