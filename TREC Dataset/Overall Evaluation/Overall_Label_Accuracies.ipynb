# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bert_label_accuracies = pd.read_csv('Banking_Data_Label_Accuracies.csv')
rnn_label_accuracies = pd.read_csv('RNN_labels_metrics_result.csv')
ft_gpt_label_accuracies = pd.read_csv('ft_coarse_label_labels_metrics_results.csv')

# %% [markdown]
# #  Accuracy, Precision, Recall Comparison Plot

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.plot(bert_label_accuracies['Labels'], bert_label_accuracies['accuracy'], label='BERT', marker='o', linestyle='-', color='blue', linewidth=2)
plt.plot(rnn_label_accuracies['Label'], rnn_label_accuracies['Accuracy'], label='RNN', marker='s', linestyle='--', color='green', linewidth=2)
plt.plot(ft_gpt_label_accuracies['Labels'], ft_gpt_label_accuracies['accuracy'], label='FT-GPT', marker='^', linestyle='-', color='orange', linewidth=2)

plt.xlabel('Labels')
plt.ylabel('Accuracy')
plt.title('Accuracy Comparison')
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(bert_label_accuracies['Labels'], bert_label_accuracies['precision'], label='BERT', marker='o', linestyle='-', color='blue', linewidth=2)
plt.plot(rnn_label_accuracies['Label'], rnn_label_accuracies['Precision'], label='RNN', marker='s', linestyle='--', color='green', linewidth=2)
plt.plot(ft_gpt_label_accuracies['Labels'], ft_gpt_label_accuracies['precision'], label='FT-GPT', marker='^', linestyle='-', color='orange', linewidth=2)

plt.xlabel('Labels')
plt.ylabel('Precision')
plt.title('Precision Comparison')
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(bert_label_accuracies['Labels'], bert_label_accuracies['recall'], label='BERT', marker='o', linestyle='-', color='blue', linewidth=2)
plt.plot(rnn_label_accuracies['Label'], rnn_label_accuracies['Recall'], label='RNN', marker='s', linestyle='--', color='green', linewidth=2)
plt.plot(ft_gpt_label_accuracies['Labels'], ft_gpt_label_accuracies['recall'], label='FT-GPT', marker='^', linestyle='-', color='orange', linewidth=2)

plt.xlabel('Labels')
plt.ylabel('Recall')
plt.title('Recall Comparison')
plt.legend()

plt.suptitle('Performance Comparison on TREC Dataset')

plt.tight_layout()
plt.show()
